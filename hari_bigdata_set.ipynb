# %% [markdown]
# <a href="https://colab.research.google.com/github/Hari-R03/Big-Data-Analysis/blob/main/hari_bigdata_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BIG DATA ANALYSIS

# %% [markdown]
# # Importing Libraries

# %%
#importing libraries from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#calling the datasets
import pandas as pd
trainset = pd.read_csv("/Train.csv")
testset = pd.read_csv("/Test.csv")

# %%
#Calling the numpy library
import numpy as np

# %%
trainset.shape
#No of rows and columns of trainset
# Out:
# (8523, 12)

# %%
testset.shape
#No of rows and columns of testset
# Out:
# (5681, 11)

# %%
#Objects of trainset
trainset.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
#Objects of Testset
testset.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
#Columns of trainset
trainset.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
#Columns of testset
testset.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
#Finding the null values in trainset
trainset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#Finding the Null value in testset
testset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
#null value difference of trainset
trainset.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#null value difference of testset
testset.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
trainset.describe()
#describing the datas of trainset
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
testset.describe()
#describing the datas of testset
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
trainset.duplicated()
#Finding any duplicates in trainset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
testset.duplicated()
#Finding the duplicates of testset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5676    False
# 5677    False
# 5678    False
# 5679    False
# 5680    False
# Length: 5681, dtype: bool

# %%
trainset.head()
#least 5 datas of trainset
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
testset.head()
#least 5 datas of testset
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
trainset.tail()
#large 5 datas of trainset
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
testset.tail()
#large 5 datas of testset
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %% [markdown]
# # Graph Plotting

# %%
trainset['Item_Fat_Content'].values
# Out:
# array(['Low Fat', 'Regular', 'Low Fat', ..., 'Low Fat', 'Regular',
#        'Low Fat'], dtype=object)

# %%
trainset['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
testset['Item_Fat_Content'].values
# Out:
# array(['Low Fat', 'reg', 'Low Fat', ..., 'Low Fat', 'Regular', 'Regular'],
#       dtype=object)

# %%
testset['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %%
#importing the mat library for graph plotting
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors

# %%
#Replacing the Item_Fat_content of the trainset
trainset["Item_Fat_Content"].replace(["LF","reg","low fat"],["Low Fat","Regular","Low Fat"],inplace=True)

# %%
#Replacing the values
trainset["Item_Fat_Content"].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
#Plotting Bar Graph for the replaced values
plt.figure(figsize=(4,4))
sns.countplot(x="Item_Fat_Content",data=trainset)
plt.xlabel("Item_Fat_Content")
plt.show()

# %% [markdown]
# *In the above Graph the Low fat content of the item is greater than Regular value.
#
# *The Regular content is half of the Low Fat content nearly 3000 in count.

# %%
#Replacing the Item_Fat_content of the testset
testset["Item_Fat_Content"].replace(["LF","reg","low fat"],["Low Fat","Regular","Low Fat"],inplace=True)

# %%
#Replaced values of the data
testset["Item_Fat_Content"].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3668
# Regular    2013
# Name: count, dtype: int64

# %%
#Plotting Graph for the replaced values
plt.figure(figsize=(4,4))
sns.countplot(x="Item_Fat_Content",data=testset)
plt.xlabel("Item_Fat_Content")
plt.show()

# %%
#Plotting the graph for Item_Type
trainset['Item_Type'].values
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', ..., 'Health and Hygiene',
#        'Snack Foods', 'Soft Drinks'], dtype=object)

# %%
trainset['Item_Type'].value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
#importing the libraries
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors

# %%
plt.figure(figsize=(25,6))
sns.countplot(x="Item_Type",data=trainset)
plt.xlabel("Item_Type")
plt.show()

# %%
plt.figure(figsize=(25,6))
sns.countplot(x="Item_Type",data=testset)
plt.xlabel("Item_Type")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
trainset["Item_Fat_Content"].replace(["LF","reg","low fat"],["Low Fat","Regular","Low Fat"],inplace=True)

# %%
ax = trainset.boxplot(column='Item_Weight',by ='Item_Fat_Content',figsize=(4,6))
ax.set_xlabel("Item_Fat_Content")
ax.set_ylabel("content")
ax.set_title("Item_Weight by Item_Fat_Content")
plt.show()

# %%
ax = testset.boxplot(column='Item_Weight',by='Item_Fat_Content',figsize=(4,6))
ax.set_xlabel("Item_Fat_Content")
ax.set_ylabel("content")
ax.set_title("Item_Weight by Item_Fat_Content")
plt.show()

# %%
plt.figure(figsize=(3,5))
plt.hist(x = 'Item_Fat_Content',data = trainset)
plt.xlabel('Item_Fat_Content')
plt.ylabel('Frequency')
plt.title('Item_Fat_Content Distribution')
plt.show()

# %%
plt.figure(figsize=(3,5))
plt.hist(x = 'Item_Fat_Content',data = testset)
plt.xlabel('Item_Fat_Content')
plt.ylabel('Item_Weight')
plt.title('Item_Fat_Content Distribution')
plt.show()

# %%
plt.figure(figsize=(3,4))
x=trainset['Item_Weight']
y=trainset['Item_Outlet_Sales']
plt.scatter(x,y)
plt.xlabel('Item_Weight')
plt.ylabel('Item_Outlet_Sales')
plt.title('Item_Weight vs Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
x = trainset['Item_MRP']
y = trainset['Item_Outlet_Sales']
plt.stem(x,y)
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')
plt.title('Item_MRP vs Item_Outlet_Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
x = testset['Item_Weight']
y = testset['Outlet_Type']
plt.stem(x,y)
plt.xlabel('Item_Weight')
plt.ylabel('Outlet_Type')
plt.title('Item_Weight vs Outlet_Type')
plt.show()

# %%
plt.figure(figsize=(6,8))
sns.countplot(y='Item_Type',data=testset)
plt.ylabel('Item_Fat_Content')
plt.show()

# %%
from matplotlib import colors
outletsize = trainset['Outlet_Size'].value_counts(normalize=True) * 100
explode = (0.1,0.1,0.1)
colours = ('yellow','red','green')
plt.pie(outletsize,labels=outletsize.index,autopct='%1.1f%%',explode=explode,colors=colours)
plt.title('% of Outlet_Size')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Label Encoder

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for col in trainset.columns:
  if trainset[col].dtype=='object':
    trainset[col]=le.fit_transform(trainset[col])

# %%
le=LabelEncoder()
for col in testset.columns:
  if testset[col].dtype=='object':
    testset[col]=le.fit_transform(testset[col])

# %%
imputer = SimpleImputer(strategy='mean')
mis_cols=['Item_Weight','Outlet_Size']
trainset[mis_cols]=imputer.fit_transform(trainset[mis_cols])

# %%
imputer=SimpleImputer(strategy='mean')
mis_cols=['Item_Weight','Outlet_Size']
testset[mis_cols]=imputer.fit_transform(testset[mis_cols])

# %%
#Normal Distribution Plot
sns.distplot(a = trainset['Item_Outlet_Sales'],kde=True, rug=True)
plt.title('Distribution plot of Item_MRP')
plt.xlabel('Item_Outlet_Sales')
plt.ylabel('density')
plt.show()
# Out:
# <ipython-input-58-4dbdf63a361e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a = trainset['Item_Outlet_Sales'],kde=True, rug=True)

# %% [markdown]
# #Handling Outriers

# %%
x = trainset.select_dtypes(include=['int64','float64'])
fig,ax = plt.subplots(figsize=(6,6))

# Use x as the data source, not as the axis
x.boxplot(ax=ax,vert=False,color='red')
plt.title('Numerical Features')
plt.show()

# %%
q1 = np.percentile(trainset['Item_Outlet_Sales'],25)
q2 = np.percentile(trainset['Item_Outlet_Sales'],75)
iqr = q2 - q1
print()

# %% [markdown]
# # Correlation Heatmap

# %%
sublist = trainset[['Item_Weight','Item_Fat_Content','Item_MRP','Outlet_Size','Outlet_Type','Item_Outlet_Sales']]
mask = np.triu(np.ones_like(sublist.corr(),dtype=bool))
fig,ax = plt.subplots(figsize=(10,10))
corr = sublist.corr() # Calculate and store the correlation matrix
sns.heatmap(corr,annot=True,cmap=sns.diverging_palette(20,220,n=200),square=True,center=0,linewidth=0.5,cbar_kws={"shrink":0.5}) # Use the calculated corr variable
plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sublist = trainset[['Item_Fat_Content','Item_Outlet_Sales','Outlet_Type','Outlet_Size','Item_Type', 'Outlet_Establishment_Year',]]
sublist_encoded = pd.get_dummies(sublist)
corr = sublist_encoded.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, square=True, linewidths=0.5, cbar_kws={"shrink": 0.5}, mask=mask)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.distplot(a = testset['Item_Weight'],kde=True, rug=True)
plt.title('Distribution plot of Item_Weight')
plt.xlabel('Item_Weight')
plt.show()
# Out:
# <ipython-input-64-fbe45227d2a7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a = testset['Item_Weight'],kde=True, rug=True)

# %%
x = testset.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(4,4))
x.boxplot(ax=ax,vert=False,color='green')
plt.title('Boxplot of Numerial Features')
plt.show()

# %%
Q1 = np.percentile(testset['Item_Weight'],25)
Q2 = np.percentile(testset['Item_Weight'],75)
iqr = Q2-q1
print(iqr,Q1,Q2)
# Out:
# -818.3974 9.195 15.85

# %%
trainset['Sales_Cube'] = np.cbrt(trainset['Item_Outlet_Sales'])

# %%
testset['Square_Root']=np.cbrt(testset['Item_MRP'])
sns.distplot(a=testset['Square_Root'],kde=True,rug=True)
plt.title('Distribution plot of Item_weight')
plt.xlabel('Item_Weight')
plt.show()
# Out:
# <ipython-input-92-d9c2f88cf2ca>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=testset['Square_Root'],kde=True,rug=True)

# %% [markdown]
# #Feature Engineering

# %%
trainset['Outlet_Age']=trainset['Outlet_Establishment_Year'].apply(lambda year:2020-year)

# %%
trainset.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          3.0
# 4   53.8614                  1                       1987          0.0
#
# ...

# %%
testset.head()
#Transforming the features
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103    20.750000                 0         0.007565         13
# 1             1067     8.300000                 1         0.038428          4
# 2             1406    14.600000                 0         0.099575         11
# 3              809     7.315000                 0         0.015388         13
# 4             1184    12.695633                 1         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999          1.0
# 1   87.3198                  2                       2007          3.0
# 2  241.7538                  0                       1998          3.0
# 3  155.0340                  2                       2007          3.0
# 4  234.2300                  5                       1985          1.0
#
#    Outlet_Location_Type  Outlet_Type  Square_Root
# ...

# %%
testset['Outlet_Age']=testset['Outlet_Establishment_Year'].apply(lambda year:2024-year)

# %%
trainset=trainset.drop(['Item_Type','Item_Identifier','Outlet_Establishment_Year','Outlet_Identifier'],axis=1)

# %%
trainset.head()
#deleting the unwanted columns
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  Outlet_Size  \
# 0         9.30                 0         0.016047  249.8092          1.0
# 1         5.92                 1         0.019278   48.2692          1.0
# 2        17.50                 0         0.016760  141.6180          1.0
# 3        19.20                 1         0.000000  182.0950          3.0
# 4         8.93                 0         0.000000   53.8614          0.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  Sales_Cube  \
# 0                     0            1          3735.1380   15.515611
# 1                     2            2           443.4228    7.625576
# 2                     0            1          2097.2700   12.800240
# 3                     2            0           732.3800    9.013888
# 4                     2            1           994.7052    9.982319
#
#    Outlet_Age
# 0          21
# 1          11
# 2          21
# 3          22
# 4          33

# %%
trainset=trainset.drop(['Item_Visibility'],axis=1)

# %%
trainset.head()
#deleting the Item Visibility column
# Out:
#    Item_Weight  Item_Fat_Content  Item_MRP  Outlet_Size  Outlet_Location_Type  \
# 0         9.30                 0  249.8092          1.0                     0
# 1         5.92                 1   48.2692          1.0                     2
# 2        17.50                 0  141.6180          1.0                     0
# 3        19.20                 1  182.0950          3.0                     2
# 4         8.93                 0   53.8614          0.0                     2
#
#    Outlet_Type  Item_Outlet_Sales  Sales_Cube  Outlet_Age
# 0            1          3735.1380   15.515611          21
# 1            2           443.4228    7.625576          11
# 2            1          2097.2700   12.800240          21
# 3            0           732.3800    9.013888          22
# 4            1           994.7052    9.982319          33

# %% [markdown]
# ```
#
# ```
#
# #Standardisation Features Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
x = trainset.iloc[:,:11]
y = trainset['Item_Outlet_Sales']

# %%
scaler=StandardScaler()
x=scaler.fit_transform(x)
x=pd.DataFrame(x)

# %%
x[0]
# Out:
# 0      -0.841872
# 1      -1.641706
# 2       1.098554
# 3       1.500838
# 4      -0.929428
#           ...
# 8518   -1.418084
# 8519   -1.059578
# 8520   -0.534243
# 8521   -1.336444
# 8522    0.459634
# Name: 0, Length: 8523, dtype: float64

# %%
x.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# 6    float64
# 7    float64
# 8    float64
# dtype: object

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.841872 -0.738147  1.747454 -0.744458 -1.369334 -0.252658  0.910601
# 1 -1.641706  1.354743 -1.489023 -0.744458  1.091569  1.002972 -1.018440
# 2  1.098554 -0.738147  0.010040 -0.744458 -1.369334 -0.252658 -0.049238
# 3  1.500838  1.354743  0.660050  1.277535  1.091569 -1.508289 -0.849103
# 4 -0.929428 -0.738147 -1.399220 -1.755454  1.091569 -0.252658 -0.695373
#
#           7         8
# 0  0.983820 -0.139541
# 1 -1.219039 -1.334103
# 2  0.225701 -0.139541
# 3 -0.831430 -0.020085
# 4 -0.561048  1.293934

# %%
testset.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103    20.750000                 0         0.007565         13
# 1             1067     8.300000                 1         0.038428          4
# 2             1406    14.600000                 0         0.099575         11
# 3              809     7.315000                 0         0.015388         13
# 4             1184    12.695633                 1         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999          1.0
# 1   87.3198                  2                       2007          3.0
# 2  241.7538                  0                       1998          3.0
# 3  155.0340                  2                       2007          3.0
# 4  234.2300                  5                       1985          1.0
#
#    Outlet_Location_Type  Outlet_Type  Square_Root  Outlet_Age
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = testset.iloc[:,:11]

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
X = pd.DataFrame(X)

# %%
X.head()
# Out:
#          0             1         2         3         4         5         6   \
# 0  0.739896  1.897460e+00 -0.740811 -1.134077  1.366916 -0.536555  1.507689
# 1  0.659085 -1.035530e+00  1.349873 -0.531850 -0.766450 -0.868937 -0.959749
# 2  1.420050  4.486336e-01 -0.740811  0.661316  0.892835  1.629848 -1.664731
# 3  0.079943 -1.267578e+00 -0.740811 -0.981416  1.366916  0.226697 -0.959749
# 4  0.921719  4.184768e-16  1.349873  1.032540 -0.766450  1.508110  0.097725
#
#          7         8         9         10
# 0  0.139891 -0.744484 -1.369215 -0.252769
# 1  1.095512  1.277707 -0.138827 -0.252769
# 2  0.020438  1.277707  1.091560 -1.507994
# 3  1.095512  1.277707 -0.138827 -0.252769
# 4 -1.532446 -0.744484  1.091560  2.257683

# %%
X.dtypes
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# 7     float64
# 8     float64
# 9     float64
# 10    float64
# dtype: object

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #Model Building

# %%
from sklearn.linear_model import LinearRegression

# %%
#For evaluating the models using the metrics
from sklearn.metrics import r2_score as R2
from sklearn.model_selection import cross_val_score as CVS

# %%
#Define the linear regression model
lr = LinearRegression()

#Train the model on training the data
lr.fit(x,y)

#Predicting the model using the testset
y_predict = lr.predict(x)

#Evaluating the training set wuth the metric values
print("R-Square value on the training set:=",lr.score(x,y))
print("_________________________________________________")

#Use cross-validation to get the R-squared score
scores = CVS(lr,x,y,cv=5)
print('CV R-squared score:',"\n")
print('Average CV R-squared score:',np.mean(scores),"\n")
# Out:
# R-Square value on the training set:= 1.0
# _________________________________________________
# CV R-squared score:
#
# Average CV R-squared score: 1.0
